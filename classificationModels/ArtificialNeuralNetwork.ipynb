# %%
import numpy as np
import pandas as pd 
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, mean_squared_error, r2_score, roc_auc_score, roc_curve, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
import warnings
warnings.filterwarnings("ignore",category = DeprecationWarning)
warnings.filterwarnings("ignore",category = FutureWarning)

# %%
df = pd.read_csv("diabetes.csv")

# %%
y = df["Outcome"]
X = df.drop(["Outcome"],axis=1)

# %%
X_train, X_test , y_train, y_test = train_test_split(X,
                                                     y,
                                                     test_size = 0.30,
                                                     random_state = 42)

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
X_train = scaler.transform(X_train)

# %%
scaler.fit(X_test)
X_test = scaler.transform(X_test)

# %%
mlpc_model = MLPClassifier().fit(X_train,y_train)
# Out:
# /Users/gokturkberkekorkut/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
mlpc_model.coefs_
# Out:
# [array([[-9.19150064e-02,  3.13796531e-01,  4.85186089e-03,
#          -4.26771225e-02, -9.75248938e-02, -3.16350195e-01,
#          -2.26411450e-01,  2.54747109e-01,  2.08387475e-01,
#           2.31316828e-02,  1.68193846e-01, -1.86919150e-01,
#          -1.79707802e-01, -6.83706593e-02,  6.86382903e-02,
#           1.78520770e-01, -1.51343179e-01, -1.16132851e-01,
#          -5.33476041e-02,  2.68220633e-01, -6.30071754e-02,
#          -3.04000994e-01, -1.62712523e-01, -5.67883793e-02,
#           1.00618317e-01,  2.91384953e-02, -5.78237492e-02,
#          -1.32342716e-01, -3.51616331e-01, -1.79930423e-01,
#          -2.11626166e-01, -3.06121925e-02,  9.36562734e-03,
#          -1.22857109e-01, -5.69814332e-01,  1.81859096e-01,
#           5.77524026e-02,  1.00887543e-02,  1.97746532e-02,
#          -1.12619476e-01,  5.16744846e-02,  1.43062157e-02,
#          -2.90538911e-02,  2.33288269e-01,  1.77257850e-02,
#          -3.05351840e-01, -1.67257496e-01,  2.03023849e-01,
#           1.76607121e-01,  1.71389972e-01,  4.67719287e-02,
#          -3.63025699e-04,  2.31936824e-01, -1.67961979e-01,
#          -1.07544719e-01, -1.67691852e-01, -1.49518421e-02,
#           2.30747795e-01, -3.36198246e-02,  1.95134767e-02,
#          -1.19036908e-02, -1.86620647e-01, -3.14399701e-01,
#          -2.76373854e-01, -9.49793996e-02,  8.59766065e-02,
#          -2.13389331e-01, -1.58890398e-01, -3.30881413e-01,
#           3.35962220e-01, -3.61847600e-02, -7.82999792e-02,
#           1.24796599e-01,  1.25223862e-01, -1.63589149e-01,
#          -6.07805919e-02,  1.96158591e-01,  1.53885207e-01,
#          -2.59319294e-01, -6.53249530e-02, -6.17648274e-03,
#          -4.05833111e-01, -2.52951186e-01,  1.51072063e-02,
#          -2.38539188e-01, -1.75043992e-01, -1.01191691e-03,
#           9.27168605e-02, -1.42899614e-01,  7.34077572e-02,
#           1.83169155e-01, -1.73444650e-01, -1.40619901e-01,
#          -2.43804094e-01, -2.63955462e-01, -8.33317919e-02,
#           1.55884777e-01,  2.43017801e-01, -9.98360128e-02,
#          -4.66943794e-01, -9.97613138e-02,  4.59825421e-02,
#           1.40738783e-01,  2.20625745e-02,  1.12661836e-01,
#          -1.59574931e-01, -4.66708213e-01, -3.71057896e-01,
#           2.76264990e-02,  1.56234343e-01, -2.63258912e-01,
#          -1.31338712e-02,  1.53904299e-01,  1.11210736e-01,
#           2.79525696e-02,  4.62985520e-02,  2.67621053e-01,
#           2.02223096e-02, -1.47175461e-01, -1.33930179e-01,
#           2.02199112e-01]]),
#  array([[ 0.14055748],
#         [-0.12758078],
#         [-0.21314217],
#         [-0.28445478],
#         [-0.01529608],
#         [-0.29992094],
#         [ 0.25031512],
#         [ 0.34866075],
#         [-0.1984316 ],
#         [ 0.36197577],
#         [ 0.22541191],
#         [ 0.16013503],
#         [ 0.24478797],
#         [-0.36494607],
#         [ 0.21203437],
#         [ 0.14793808],
#         [ 0.16746283],
#         [-0.34392649],
#         [-0.27716312],
#         [ 0.18158368],
#         [ 0.15849554],
#         [-0.21768472],
#         [-0.19791367],
#         [ 0.20316496],
#         [-0.20314776],
#         [-0.22343257],
#         [-0.14909394],
#         [-0.31297797],
#         [ 0.36663019],
#         [ 0.328915  ],
#         [-0.3384306 ],
#         [-0.24467808],
#         [-0.08959219],
#         [-0.09923129],
#         [ 0.3392785 ],
#         [ 0.2389724 ],
#         [-0.15291298],
#         [-0.32526237],
#         [-0.18069315],
#         [-0.19592608],
#         [-0.46441476],
#         [-0.35669248],
#         [ 0.16847429],
#         [-0.28614139],
#         [-0.48684655],
#         [-0.27650446],
#         [ 0.22009916],
#         [ 0.36240792],
#         [ 0.11330414],
#         [-0.26472986],
#         [-0.44052753],
#         [-0.23458526],
#         [ 0.27276674],
#         [ 0.16218387],
#         [ 0.22464242],
#         [-0.22907285],
#         [ 0.3149547 ],
#         [ 0.18067262],
#         [-0.25797506],
#         [ 0.1326148 ],
#         [ 0.23293212],
#         [-0.39867147],
#         [-0.23609328],
#         [-0.20287065],
#         [ 0.18960231],
#         [ 0.11454772],
#         [-0.40966013],
#         [ 0.42198848],
#         [ 0.34641518],
#         [ 0.37963922],
#         [-0.06775466],
#         [ 0.19248521],
#         [-0.1892166 ],
#         [ 0.18477356],
#         [-0.31369341],
#         [-0.15085428],
#         [-0.31260331],
#         [ 0.2105934 ],
#         [-0.30206013],
#         [-0.44916301],
#         [ 0.32111507],
#         [ 0.18509674],
#         [-0.11368492],
#         [-0.21495247],
#         [-0.35668298],
#         [-0.26688961],
#         [-0.30583287],
#         [ 0.14687027],
#         [ 0.30123779],
#         [-0.27653815],
#         [-0.20642813],
#         [ 0.04234163],
#         [ 0.27557409],
#         [ 0.14996509],
#         [ 0.39990617],
#         [ 0.14927932],
#         [ 0.24336249],
#         [ 0.14327473],
#         [-0.25668417],
#         [ 0.42905575]])]

# %%
y_pred = mlpc_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7402597402597403

# %% [markdown]
# ### Model Tuning

# %%
mlpc_params = {"alpha":[1,5,0.1,0.01,0.03,0.005,0.0001],
               "hidden_layer_sizes" : [(10,10),(100,100,100),(100,100),(3,5)]}

# %%
mlpc = MLPClassifier(solver="lbfgs",max_iter = 10000)

# %%
mlpc_cv_model = GridSearchCV(mlpc,mlpc_params,cv=10,n_jobs=-1,verbose=2).fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 28 candidates, totalling 280 fits
# [CV] END ...............alpha=1, hidden_layer_sizes=(10, 10); total time=   0.2s
# [CV] END ...............alpha=1, hidden_layer_sizes=(10, 10); total time=   0.3s
# [CV] END ...............alpha=1, hidden_layer_sizes=(10, 10); total time=   0.4s
# [CV] END ...............alpha=1, hidden_layer_sizes=(10, 10); total time=   0.4s
# [CV] END ...............alpha=1, hidden_layer_sizes=(10, 10); total time=   0.4s
# [CV] END ...............alpha=1, hidden_layer_sizes=(10, 10); total time=   0.5s
# [CV] END ...............alpha=1, hidden_layer_sizes=(10, 10); total time=   0.6s
# [CV] END ...............alpha=1, hidden_layer_sizes=(10, 10); total time=   0.6s
# [CV] END ...............alpha=1, hidden_layer_sizes=(10, 10); total time=   0.7s
# [CV] END ...............alpha=1, hidden_layer_sizes=(10, 10); total time=   1.0s
# [CV] END ........alpha=1, hidden_layer_sizes=(100, 100, 100); total time=   7.2s
# [CV] END ........alpha=1, hidden_layer_sizes=(100, 100, 100); total time=   8.5s
# [CV] END ........alpha=1, hidden_layer_sizes=(100, 100, 100); total time=  11.3s
# [CV] END ........alpha=1, hidden_layer_sizes=(100, 100, 100); total time=  13.5s
# [CV] END ........alpha=1, hidden_layer_sizes=(100, 100, 100); total time=  14.0s
# [CV] END ........alpha=1, hidden_layer_sizes=(100, 100, 100); total time=  15.3s
# [CV] END .............alpha=1, hidden_layer_sizes=(100, 100); total time=   7.5s
# [CV] END ........alpha=1, hidden_layer_sizes=(100, 100, 100); total time=  17.9s
# [CV] END .............alpha=1, hidden_layer_sizes=(100, 100); total time=  11.2s
# [CV] END ........alpha=1, hidden_layer_sizes=(100, 100, 100); total time=  18.9s
# [CV] END ........alpha=1, hidden_layer_sizes=(100, 100, 100); total time=  19.7s
# [CV] END .................alpha=1, hidden_layer_sizes=(3, 5); total time=   0.1s
# [CV] END .................alpha=1, hidden_layer_sizes=(3, 5); total time=   0.1s
# [CV] END .................alpha=1, hidden_layer_sizes=(3, 5); total time=   0.1s
# [CV] END .................alpha=1, hidden_layer_sizes=(3, 5); total time=   0.1s
# [CV] END .................alpha=1, hidden_layer_sizes=(3, 5); total time=   0.1s
# [CV] END .................alpha=1, hidden_layer_sizes=(3, 5); total time=   0.0s
# [CV] END .................alpha=1, hidden_layer_sizes=(3, 5); total time=   0.0s
# [CV] END .................alpha=1, hidden_layer_sizes=(3, 5); total time=   0.1s
# [CV] END .................alpha=1, hidden_layer_sizes=(3, 5); total time=   0.2s
# [CV] END .................alpha=1, hidden_layer_sizes=(3, 5); total time=   0.1s
# [CV] END ...............alpha=5, hidden_layer_sizes=(10, 10); total time=   0.1s
# [CV] END ...............alpha=5, hidden_layer_sizes=(10, 10); total time=   0.2s
# [CV] END ...............alpha=5, hidden_layer_sizes=(10, 10); total time=   0.2s
# [CV] END ...............alpha=5, hidden_layer_sizes=(10, 10); total time=   0.1s
# [CV] END ...............alpha=5, hidden_layer_sizes=(10, 10); total time=   0.4s
# [CV] END ...............alpha=5, hidden_layer_sizes=(10, 10); total time=   0.1s
# [CV] END ...............alpha=5, hidden_layer_sizes=(10, 10); total time=   0.2s
# [CV] END ...............alpha=5, hidden_layer_sizes=(10, 10); total time=   0.2s
# [CV] END ...............alpha=5, hidden_layer_sizes=(10, 10); total time=   0.1s
# [CV] END ...............alpha=5, hidden_layer_sizes=(10, 10); total time=   0.1s
# [CV] END .............alpha=1, hidden_layer_sizes=(100, 100); total time=   8.2s
# [CV] END .............alpha=1, hidden_layer_sizes=(100, 100); total time=   6.6s
# [CV] END .............alpha=1, hidden_layer_sizes=(100, 100); total time=   6.5s
# [CV] END .............alpha=1, hidden_layer_sizes=(100, 100); total time=  13.1s
# [CV] END ........alpha=1, hidden_layer_sizes=(100, 100, 100); total time=  24.7s
# [CV] END .............alpha=1, hidden_layer_sizes=(100, 100); total time=   9.1s
# [CV] END .............alpha=1, hidden_layer_sizes=(100, 100); total time=   9.4s
# [CV] END .............alpha=1, hidden_layer_sizes=(100, 100); total time=  15.2s
# [CV] END .............alpha=1, hidden_layer_sizes=(100, 100); total time=  15.6s
# [CV] END ........alpha=5, hidden_layer_sizes=(100, 100, 100); total time=  11.3s
# [CV] END ........alpha=5, hidden_layer_sizes=(100, 100, 100); total time=  12.6s
# [CV] END ........alpha=5, hidden_layer_sizes=(100, 100, 100); total time=  13.8s
# [CV] END .............alpha=5, hidden_layer_sizes=(100, 100); total time=   7.3s
# [CV] END .............alpha=5, hidden_layer_sizes=(100, 100); total time=   2.4s
# [CV] END .............alpha=5, hidden_layer_sizes=(100, 100); total time=   6.1s
# [CV] END ........alpha=5, hidden_layer_sizes=(100, 100, 100); total time=  17.6s
# [CV] END ........alpha=5, hidden_layer_sizes=(100, 100, 100); total time=  20.8s
# [CV] END ........alpha=5, hidden_layer_sizes=(100, 100, 100); total time=  18.0s
# [CV] END ........alpha=5, hidden_layer_sizes=(100, 100, 100); total time=  19.6s
# [CV] END ........alpha=5, hidden_layer_sizes=(100, 100, 100); total time=  17.4s
# [CV] END .............alpha=5, hidden_layer_sizes=(100, 100); total time=   6.8s
# [CV] END .................alpha=5, hidden_layer_sizes=(3, 5); total time=   0.0s
# [CV] END .................alpha=5, hidden_layer_sizes=(3, 5); total time=   0.0s
# [CV] END .............alpha=5, hidden_layer_sizes=(100, 100); total time=   7.1s
# [CV] END .................alpha=5, hidden_layer_sizes=(3, 5); total time=   0.0s
# [CV] END .................alpha=5, hidden_layer_sizes=(3, 5); total time=   0.0s
# [CV] END .................alpha=5, hidden_layer_sizes=(3, 5); total time=   0.0s
# [CV] END .................alpha=5, hidden_layer_sizes=(3, 5); total time=   0.1s
# [CV] END .................alpha=5, hidden_layer_sizes=(3, 5); total time=   0.1s
# [CV] END .................alpha=5, hidden_layer_sizes=(3, 5); total time=   0.1s
# [CV] END .................alpha=5, hidden_layer_sizes=(3, 5); total time=   0.1s
# [CV] END .................alpha=5, hidden_layer_sizes=(3, 5); total time=   0.1s
# [CV] END .............alpha=0.1, hidden_layer_sizes=(10, 10); total time=   0.2s
# [CV] END .............alpha=0.1, hidden_layer_sizes=(10, 10); total time=   0.2s
# [CV] END .............alpha=0.1, hidden_layer_sizes=(10, 10); total time=   0.1s
# [CV] END .............alpha=0.1, hidden_layer_sizes=(10, 10); total time=   0.5s
# [CV] END .............alpha=0.1, hidden_layer_sizes=(10, 10); total time=   0.1s
# [CV] END .............alpha=0.1, hidden_layer_sizes=(10, 10); total time=   0.7s
# [CV] END .............alpha=0.1, hidden_layer_sizes=(10, 10); total time=   0.2s
# [CV] END .............alpha=0.1, hidden_layer_sizes=(10, 10); total time=   0.2s
# [CV] END .............alpha=0.1, hidden_layer_sizes=(10, 10); total time=   0.8s
# [CV] END ........alpha=5, hidden_layer_sizes=(100, 100, 100); total time=  23.0s
# [CV] END .............alpha=0.1, hidden_layer_sizes=(10, 10); total time=   1.8s
# [CV] END .............alpha=5, hidden_layer_sizes=(100, 100); total time=  11.0s
# [CV] END .............alpha=5, hidden_layer_sizes=(100, 100); total time=   9.2s
# [CV] END .............alpha=5, hidden_layer_sizes=(100, 100); total time=  11.2s
# [CV] END .............alpha=5, hidden_layer_sizes=(100, 100); total time=   6.2s
# [CV] END ........alpha=5, hidden_layer_sizes=(100, 100, 100); total time=  32.6s
# [CV] END .............alpha=5, hidden_layer_sizes=(100, 100); total time=   9.7s
# [CV] END ......alpha=0.1, hidden_layer_sizes=(100, 100, 100); total time=   7.7s
# [CV] END ......alpha=0.1, hidden_layer_sizes=(100, 100, 100); total time=  11.2s
# [CV] END ......alpha=0.1, hidden_layer_sizes=(100, 100, 100); total time=   9.0s
# [CV] END ......alpha=0.1, hidden_layer_sizes=(100, 100, 100); total time=  11.3s
# [CV] END ......alpha=0.1, hidden_layer_sizes=(100, 100, 100); total time=  11.2s
# [CV] END ......alpha=0.1, hidden_layer_sizes=(100, 100, 100); total time=  11.6s
# [CV] END ......alpha=0.1, hidden_layer_sizes=(100, 100, 100); total time=  11.7s
# [CV] END ...........alpha=0.1, hidden_layer_sizes=(100, 100); total time=   4.8s
# [CV] END ...........alpha=0.1, hidden_layer_sizes=(100, 100); total time=   6.0s
# [CV] END ...............alpha=0.1, hidden_layer_sizes=(3, 5); total time=   0.0s
# [CV] END ...............alpha=0.1, hidden_layer_sizes=(3, 5); total time=   0.1s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 mlpc_cv_model = GridSearchCV(mlpc,mlpc_params,cv=10,n_jobs=-1,verbose=2).fit(X_train,y_train)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1419, in GridSearchCV._run_search(self, evaluate_candidates)
#    1417 def _run_search(self, evaluate_candidates):
#    1418     """Search all candidates in param_grid"""
# -> 1419     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File ~/anaconda3/lib/python3.11/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/anaconda3/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
mlpc_cv_model.best_params_
# Out:
# {'alpha': 5, 'hidden_layer_sizes': (3, 5)}

# %%
mlpc_cv_model.best_score_
# Out:
# 0.7337526205450734

# %%
mlpc_tuned = MLPClassifier(solver="lbfgs",alpha=5,hidden_layer_sizes=(3,5),max_iter=1000).fit(X_train,y_train)

# %%
y_pred =mlpc_tuned.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7142857142857143

# %% [markdown]
# # CART(Classification and Regression Tree)

# %% [markdown]
# Amac veri seti icerisindeki karmasik yapilari basit karar yapilarina donusturmektir

# %%
X_train, X_test , y_train, y_test = train_test_split(X,
                                                     y,
                                                     test_size = 0.30,
                                                     random_state = 42)

# %%
cart_model = DecisionTreeClassifier().fit(X_train,y_train)

# %%
cart_model
# Out:
# DecisionTreeClassifier()

# %%
y_pred = cart_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7012987012987013

# %%
cart = DecisionTreeClassifier()

# %%
cart_params = {"max_depth": [1,3,5,8,10],
               "min_samples_split":[2,3,5,10,20,50]}

# %%
cart_cv_model = GridSearchCV(cart,cart_params,cv=10,n_jobs=-1,verbose=2).fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# [CV] END ...................max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=5; total time=   0.0s[CV] END ...................max_depth=1, min_samples_split=2; total time=   0.0s
#
# [CV] END ...................max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=10; total time=   0.0s[CV] END ..................max_depth=3, min_samples_split=20; total time=   0.0s
#
# [CV] END ..................max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ...................max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=10; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=10; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=10; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=10; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=20; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=3; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=20; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=3; total time=   0.0s
# [CV] END ..................max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=20; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=3; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=3; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=20; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=3; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=50; total time=   0.0s
# [CV] END ...................max_depth=8, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=50; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=8, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .................max_depth=10, min_samples_split=50; total time=   0.0s

# %%
cart_cv_model.best_params_
# Out:
# {'max_depth': 5, 'min_samples_split': 20}

# %%
#final model

# %%
cart_tuned = DecisionTreeClassifier(max_depth=5,min_samples_split=20).fit(X_train,y_train)

# %%
y_pred = cart_tuned.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7532467532467533
